# %%
import os

import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

from collections import Counter

from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import accuracy_score

# %%
optimizer = "Adam"
loss_function = "categorical_crossentropy"
epochs = 60
batch_size = 128
learning_rate = .01
img_width = 32
img_height = 32
n = 5
num_class = 10
input_shape = (img_width, img_height, 3)

# %%
#load CIFAR-10 DATA
def load_data():
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    
    #normalize pixel values to 0-1 to simplify training
    x_train = x_train.astype("float32") / 255.0
    x_test = x_test.astype("float32") / 255.0
    
    #flatten and encode labels
    y_train = y_train.flatten()
    y_test =  y_test.flatten()
    
    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = load_data()

# %%
#AlexNet Model setup - includes matching parameters with MIAShield
def create_model(input_shape, num_class):
    model = Sequential()

    #Layer 1 - Conv2D with MaxPooling
    model.add(Conv2D(48, (3, 3), strides = (2, 2), activation = "relu", padding = "same", input_shape = input_shape))
    model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
    model.add(BatchNormalization())

    #Layer 2 - Conv2D with MaxPooling 
    model.add(Conv2D(96, (3, 3), activation = "relu", padding = "same"))
    model.add(MaxPooling2D(pool_size = (3, 3), strides = (2, 2)))
    model.add(BatchNormalization())

    #Layer 3 - Conv2D
    model.add(Conv2D(192, (3, 3), activation = "relu", padding = "same"))

    #Layer 4 - Conv2D
    model.add(Conv2D(192, (3, 3), activation = "relu", padding = "same"))

    #Layer 5 - Conv2D with MaxPooling
    model.add(Conv2D(256, (3, 3), activation = "relu", padding = "same"))
    model.add(MaxPooling2D(pool_size = (3, 3), strides = (2, 2)))
    model.add(BatchNormalization())

    #flatten
    model.add(Flatten())

    #Fully Connected layer 1
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(.50))
            
    #Fully Connected layer 2
    model.add(Dense(256, activation = "relu"))
    model.add(Dropout(.50))

    #Output layer
    model.add(Dense(num_class, activation = "softmax"))

    return model

# %%
#base model uses 5 disjoint datasets for training
X = x_train
Y = y_train
idx = np.arange(len(X))

skf = StratifiedKFold(n_splits = n, shuffle = True, random_state = 42)
skf.get_n_splits(X, Y)
    
for i, (_, test_index) in enumerate(skf.split(X,Y)):
    Xi = X[test_index]
    Yi = Y[test_index]
    Y_onehot = to_categorical(Yi, num_classes = num_class)
    index_split = idx[test_index]
    
    globals()[f'x_train_split{i}'] = Xi
    globals()[f'y_train_split{i}'] = Yi
    globals()[f'y_onehot{i}'] = Y_onehot
    globals()[f'index_split{i}'] = index_split

# %%
#recombine indices from across all splits
all_indices = np.concatenate([globals()[f'index_split{i}'] for i in range(n)])
print(f"Total number of indices: {len(all_indices)}")

# check for duplicate values to ensure disjointedness
has_duplicates = len(all_indices) != len(np.unique(all_indices))
print("Duplicate Indices Present:", has_duplicates)

# check to ensure full dataset is represented
covers_all = len(all_indices) == len(X)
print("Coverage of Dataset Achieved:", covers_all)
# Out:
# Total number of indices: 50000
# Duplicate Indices Present: False
# Coverage of Dataset Achieved: True

# %%
#verify that label distribution is consistent across all data partitions
for i in range(n):
    labels = globals()[f'y_train_split{i}']
    counts = Counter(labels)
    print(f"Fold {i} label distribution:", dict(counts))
# Out:
# Fold 0 label distribution: {7: 1000, 9: 1000, 4: 1000, 6: 1000, 5: 1000, 0: 1000, 3: 1000, 2: 1000, 1: 1000, 8: 1000}
# Fold 1 label distribution: {6: 1000, 9: 1000, 4: 1000, 8: 1000, 7: 1000, 1: 1000, 5: 1000, 3: 1000, 0: 1000, 2: 1000}
# Fold 2 label distribution: {9: 1000, 1: 1000, 3: 1000, 6: 1000, 4: 1000, 7: 1000, 2: 1000, 0: 1000, 8: 1000, 5: 1000}
# Fold 3 label distribution: {1: 1000, 2: 1000, 3: 1000, 4: 1000, 0: 1000, 9: 1000, 5: 1000, 8: 1000, 6: 1000, 7: 1000}
# Fold 4 label distribution: {7: 1000, 2: 1000, 0: 1000, 9: 1000, 3: 1000, 1: 1000, 8: 1000, 5: 1000, 4: 1000, 6: 1000}

# %%
#EO uses 2.5k members from each Dtrain split
x_train_sample = []
y_train_sample = []
y_onehot_sample = []
index_original_eo = []
mem_per_split = 2500
nonmem = 5000

for i in range(n):
    Xi = globals()[f'x_train_split{i}']
    Yi = globals()[f'y_train_split{i}']
    y_onehot_i = globals()[f'y_onehot{i}']
    split_original_index = globals()[f'index_split{i}']
    
    stratified_choice = StratifiedShuffleSplit(n_splits = 1, test_size = mem_per_split, random_state = 42)
    
    for _, index_choice in stratified_choice.split(Xi, Yi):
        x_train_sample.append(Xi[index_choice])
        y_train_sample.append(Yi[index_choice])
        y_onehot_sample.append(y_onehot_i[index_choice])
        index_original_eo.extend(split_original_index[index_choice])

#EO uses 5k nonmembers (from Dtest)
stratified_choice_test = StratifiedShuffleSplit(n_splits = 1, test_size = nonmem, random_state = 42)
for _, index_choice_test in stratified_choice_test.split(x_test, y_test):
    x_test_eo = x_test[index_choice_test]
    y_test_eo = y_test[index_choice_test]
    index_test_eo = index_choice_test
    y_test_onehot = to_categorical(y_test_eo, num_classes = num_class)

x_train_eo = np.concatenate(x_train_sample + [x_test_eo], axis = 0)
y_train_eo = np.concatenate(y_train_sample + [y_test_eo], axis = 0)
y_onehot_eo = np.concatenate(y_onehot_sample + [y_test_onehot], axis=0)

members = mem_per_split * n
nonmembers = nonmem
membership_labels = np.concatenate([np.ones(members), np.zeros(nonmem)])

globals()[f'x_train_eo'] = x_train_eo
globals()[f'y_train_eo'] = y_train_eo
globals()[f'y_onehot_eo'] = y_onehot_eo
globals()[f'index_eo_original'] = index_original_eo
globals()[f'index_eo_test'] = index_test_eo
globals()[f'membership_labels_eo'] = membership_labels

# %%
# Split back into members and nonmembers to verify breakdowns
members = y_train_eo[:mem_per_split * n]
nonmembers = y_train_eo[mem_per_split * n:]

print(f'Expected Member Count = {n * mem_per_split}')
print(f'Actual Member Count = {len(members)}')
print(f'Expected Nonmember Count = {nonmem}')
print(f'Actual Nonmember Count = {len(nonmembers)}')

# Count stratification of classes and total counts
member_counts = Counter(members)
nonmember_counts = Counter(nonmembers)

print(f'Expected Member Count Per Class = {mem_per_split * n / num_class}')
print(f'Actual Member Count = {member_counts}')
print(f'Expected Nonmember Count Per Class = {nonmem / num_class}')
print(f'Actual Nonmember Count = {nonmember_counts}')
# Out:
# Expected Member Count = 12500
# Actual Member Count = 12500
# Expected Nonmember Count = 5000
# Actual Nonmember Count = 5000
# Expected Member Count Per Class = 1250.0
# Actual Member Count = Counter({6: 1250, 4: 1250, 3: 1250, 9: 1250, 0: 1250, 2: 1250, 1: 1250, 7: 1250, 5: 1250, 8: 1250})
# Expected Nonmember Count Per Class = 500.0
# Actual Nonmember Count = Counter({8: 500, 9: 500, 3: 500, 1: 500, 6: 500, 7: 500, 5: 500, 0: 500, 2: 500, 4: 500})

# %%
#DTestMiashield uses 5k members from Dtrain - must be disjoint with EO
mems = 5000
nonmems = 5000
x_train_mia = []
y_train_mia = []
y_onehot_mia = []
index_original_mia = []

all_training_indices= np.arange(len(x_train))
remaining_training_indices = np.setdiff1d(all_training_indices, index_eo_original)

for i in range(n):
    Xi = globals()[f'x_train_split{i}']
    Yi = globals()[f'y_train_split{i}']
    y_onehot_i = globals()[f'y_onehot{i}']
    split_original_index = globals()[f'index_split{i}']

    Xi_remaining = Xi[np.isin(split_original_index, np.array(remaining_training_indices))]
    Yi_remaining = Yi[np.isin(split_original_index, np.array(remaining_training_indices))]
    index_remaining = split_original_index[np.isin(split_original_index, np.array(remaining_training_indices))]
    
    stratified_choice = StratifiedShuffleSplit(n_splits = 1, test_size = mems // n, random_state = 42)
    
    for _, index_choice in stratified_choice.split(Xi_remaining, Yi_remaining):
        x_train_mia.append(Xi_remaining[index_choice])
        y_train_mia.append(Yi_remaining[index_choice])
        y_onehot_mia.append(y_onehot_i[index_choice])
        index_original_mia.extend(index_remaining[index_choice])

#DtestMiashield uses 5k nonmembers (from Dtest) - must be disjoinst with EO
all_testing_indices= np.arange(len(x_test))
remaining_testing_indices = np.setdiff1d(all_testing_indices, index_eo_test)

x_test_rem = x_test[remaining_testing_indices]
y_test_rem = y_test[remaining_testing_indices]
index_text_mia = remaining_testing_indices
y_test_onehot = to_categorical(y_test_rem, num_classes = num_class)

x_test_mia = np.concatenate(x_train_mia + [x_test_rem], axis = 0)
y_test_mia = np.concatenate(y_train_mia + [y_test_rem], axis = 0)
y_onehot_mia = np.concatenate(y_onehot_mia + [y_test_onehot], axis=0)

membership_labels = np.concatenate([np.ones(mems), np.zeros(nonmem)])

globals()[f'x_test_mia'] = x_test_mia
globals()[f'y_test_mia'] = y_test_mia
globals()[f'y_onehot_mia'] = y_onehot_mia
globals()[f'index_original_mia'] = index_original_mia
globals()[f'index_test_mia'] = index_test_mia
globals()[f'membership_labels_eo'] = membership_labels

# %%
# Split back into members and nonmembers to verify breakdowns
members = y_test_mia[:mems]
nonmembers = y_test_mia[mems:]

print(f'Expected Member Count = {mems}')
print(f'Actual Member Count = {len(members)}')
print(f'Expected Nonmember Count = {nonmems}')
print(f'Actual Nonmember Count = {len(nonmembers)}')

# Count stratification of classes and total counts
member_counts = Counter(members)
nonmember_counts = Counter(nonmembers)

print(f'Expected Member Count Per Class = {mems / num_class}')
print(f'Actual Member Count = {member_counts}')
print(f'Expected Nonmember Count Per Class = {nonmems / num_class}')
print(f'Actual Nonmember Count = {nonmember_counts}')

#check for disjointedness with EO
overlap = np.intersect1d(index_original_eo, index_original_mia)
print(f'Expected overlap = 0')
print(f'Actual overlap = {len(overlap)}')
# Out:
# Expected Member Count = 5000
# Actual Member Count = 5000
# Expected Nonmember Count = 5000
# Actual Nonmember Count = 5000
# Expected Member Count Per Class = 500.0
# Actual Member Count = Counter({4: 500, 3: 500, 1: 500, 9: 500, 5: 500, 8: 500, 2: 500, 0: 500, 6: 500, 7: 500})
# Expected Nonmember Count Per Class = 500.0
# Actual Nonmember Count = Counter({0: 500, 6: 500, 3: 500, 1: 500, 9: 500, 8: 500, 7: 500, 5: 500, 4: 500, 2: 500})
# Expected overlap = 0
# Actual overlap = 0

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range = 10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range = .2,
    zoom_range=0.2,
    horizontal_flip=True,
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
for i in range(0, n):
    trained_model = create_model(input_shape, num_class)
    optimizer = tf.keras.optimizers.Adam(learning_rate=.01)
    loss_function = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
    trained_model.compile(optimizer = optimizer, loss = loss_function, metrics = ['accuracy'])
    trained_model.summary()
    model_data = globals()[f'x_train_split{i}']
    target_data = globals()[f'y_train_split{i}']
    print(target_data.shape)
    datagen = train_datagen
    steps_per_epoch = len(model_data) // batch_size

    globals()[f'history{i}'] = trained_model.fit(datagen.flow(model_data, target_data, batch_size=128, shuffle=True),
                    steps_per_epoch = steps_per_epoch, epochs=epochs, validation_data=(x_test, y_test))
    globals()[f'model{i}'] = trained_model
# Out:
# C:\Users\Owner\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_70 (Conv2D)                   │ (None, 16, 16, 48)          │           1,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_42 (MaxPooling2D)      │ (None, 8, 8, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_42               │ (None, 8, 8, 48)            │             192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_71 (Conv2D)                   │ (None, 8, 8, 96)            │          41,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_43 (MaxPooling2D)      │ (None, 3, 3, 96)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_43               │ (None, 3, 3, 96)            │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_72 (Conv2D)                   │ (None, 3, 3, 192)           │         166,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_73 (Conv2D)                   │ (None, 3, 3, 192)           │         331,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_74 (Conv2D)                   │ (None, 3, 3, 256)           │         442,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_44 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_44               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_14 (Flatten)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_42 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_43 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_44 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# C:\Users\Owner\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.1176 - loss: 2.7473 - val_accuracy: 0.1027 - val_loss: 2.6456
# Epoch 2/60
#  1/78 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1719 - loss: 2.3065
# C:\Users\Owner\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1719 - loss: 2.3065 - val_accuracy: 0.1000 - val_loss: 2.7831
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.1637 - loss: 2.1947 - val_accuracy: 0.1001 - val_loss: 4.5592
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1406 - loss: 2.1723 - val_accuracy: 0.1001 - val_loss: 4.5728
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.1622 - loss: 2.1384 - val_accuracy: 0.1687 - val_loss: 3.1203
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2031 - loss: 2.0889 - val_accuracy: 0.1224 - val_loss: 2.6919
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.1947 - loss: 2.1038 - val_accuracy: 0.1008 - val_loss: 12.3866
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1172 - loss: 2.1142 - val_accuracy: 0.1003 - val_loss: 13.0271
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.1961 - loss: 2.0784 - val_accuracy: 0.1397 - val_loss: 40.5596
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.1484 - loss: 2.0258 - val_accuracy: 0.1577 - val_loss: 43.0723
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.2203 - loss: 1.9893 - val_accuracy: 0.1355 - val_loss: 48.7580
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2500 - loss: 1.9811 - val_accuracy: 0.1373 - val_loss: 52.5873
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.2528 - loss: 1.9137 - val_accuracy: 0.1168 - val_loss: 237.5842
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2031 - loss: 1.8131 - val_accuracy: 0.1176 - val_loss: 224.4705
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.2624 - loss: 1.8784 - val_accuracy: 0.1212 - val_loss: 385.4510
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2422 - loss: 1.8132 - val_accuracy: 0.1274 - val_loss: 361.2205
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.2890 - loss: 1.8541 - val_accuracy: 0.1330 - val_loss: 474.9496
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2578 - loss: 1.8986 - val_accuracy: 0.1356 - val_loss: 457.1182
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3055 - loss: 1.8116 - val_accuracy: 0.1140 - val_loss: 838.2332
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2891 - loss: 1.8450 - val_accuracy: 0.1153 - val_loss: 798.9371
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3021 - loss: 1.8053 - val_accuracy: 0.1205 - val_loss: 1156.8877
# Epoch 22/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3516 - loss: 1.7312 - val_accuracy: 0.1232 - val_loss: 1172.0773
# Epoch 23/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3186 - loss: 1.7585 - val_accuracy: 0.1000 - val_loss: 865.6531
# Epoch 24/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2422 - loss: 1.8522 - val_accuracy: 0.0982 - val_loss: 594.4816
# Epoch 25/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3124 - loss: 1.7940 - val_accuracy: 0.1042 - val_loss: 2994.6958
# Epoch 26/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3203 - loss: 1.7645 - val_accuracy: 0.1097 - val_loss: 2945.8279
# Epoch 27/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3197 - loss: 1.7506 - val_accuracy: 0.1256 - val_loss: 2765.6262
# Epoch 28/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3203 - loss: 1.7273 - val_accuracy: 0.1211 - val_loss: 2740.9365
# Epoch 29/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3336 - loss: 1.7239 - val_accuracy: 0.1002 - val_loss: 4420.0400
# Epoch 30/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3281 - loss: 1.7550 - val_accuracy: 0.1009 - val_loss: 4298.4863
# Epoch 31/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3539 - loss: 1.7050 - val_accuracy: 0.1011 - val_loss: 4259.5059
# Epoch 32/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2891 - loss: 1.8058 - val_accuracy: 0.1011 - val_loss: 4302.2866
# Epoch 33/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3659 - loss: 1.6833 - val_accuracy: 0.1000 - val_loss: 5956.9580
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4531 - loss: 1.6153 - val_accuracy: 0.1008 - val_loss: 5660.2520
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3772 - loss: 1.6695 - val_accuracy: 0.1524 - val_loss: 3337.2720
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3281 - loss: 1.7775 - val_accuracy: 0.1415 - val_loss: 3473.1509
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3862 - loss: 1.6617 - val_accuracy: 0.1475 - val_loss: 1677.4753
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3438 - loss: 1.5776 - val_accuracy: 0.1492 - val_loss: 1684.6464
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3895 - loss: 1.6253 - val_accuracy: 0.1081 - val_loss: 2673.3943
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4297 - loss: 1.5259 - val_accuracy: 0.1148 - val_loss: 2498.6665
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4010 - loss: 1.6202 - val_accuracy: 0.1436 - val_loss: 3045.7068
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4375 - loss: 1.6094 - val_accuracy: 0.1442 - val_loss: 3280.8501
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4117 - loss: 1.6005 - val_accuracy: 0.1108 - val_loss: 3342.1421
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3438 - loss: 1.5165 - val_accuracy: 0.1124 - val_loss: 3177.8130
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.4143 - loss: 1.6272 - val_accuracy: 0.1001 - val_loss: 1854.6888
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4219 - loss: 1.5987 - val_accuracy: 0.1018 - val_loss: 1611.8026
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4120 - loss: 1.5872 - val_accuracy: 0.1000 - val_loss: 3611.2517
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4297 - loss: 1.6203 - val_accuracy: 0.1000 - val_loss: 3619.4756
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4122 - loss: 1.6037 - val_accuracy: 0.1041 - val_loss: 1931.4810
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3828 - loss: 1.5226 - val_accuracy: 0.1096 - val_loss: 1752.0020
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4459 - loss: 1.5461 - val_accuracy: 0.1000 - val_loss: 1095.5364
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3672 - loss: 1.5250 - val_accuracy: 0.1002 - val_loss: 1076.5217
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4470 - loss: 1.5232 - val_accuracy: 0.1003 - val_loss: 366.3237
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5000 - loss: 1.3667 - val_accuracy: 0.1003 - val_loss: 399.7103
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4693 - loss: 1.5178 - val_accuracy: 0.1051 - val_loss: 545.8885
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4609 - loss: 1.5854 - val_accuracy: 0.1050 - val_loss: 600.8605
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.4457 - loss: 1.5509 - val_accuracy: 0.1784 - val_loss: 253.9324
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4766 - loss: 1.6363 - val_accuracy: 0.1733 - val_loss: 289.0605
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.4529 - loss: 1.5348 - val_accuracy: 0.1236 - val_loss: 412.3050
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5078 - loss: 1.4357 - val_accuracy: 0.1299 - val_loss: 459.5768
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_75 (Conv2D)                   │ (None, 16, 16, 48)          │           1,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_45 (MaxPooling2D)      │ (None, 8, 8, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_45               │ (None, 8, 8, 48)            │             192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_76 (Conv2D)                   │ (None, 8, 8, 96)            │          41,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_46 (MaxPooling2D)      │ (None, 3, 3, 96)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_46               │ (None, 3, 3, 96)            │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_77 (Conv2D)                   │ (None, 3, 3, 192)           │         166,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_78 (Conv2D)                   │ (None, 3, 3, 192)           │         331,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_79 (Conv2D)                   │ (None, 3, 3, 256)           │         442,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_47 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_47               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_15 (Flatten)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_45 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_30 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_46 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_31 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_47 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.1332 - loss: 2.6319 - val_accuracy: 0.1003 - val_loss: 2.3047
# Epoch 2/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1875 - loss: 2.1021 - val_accuracy: 0.1038 - val_loss: 2.2940
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.1599 - loss: 2.1585 - val_accuracy: 0.1459 - val_loss: 2.4731
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1094 - loss: 2.2133 - val_accuracy: 0.1008 - val_loss: 4.0830
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.1778 - loss: 2.0867 - val_accuracy: 0.1003 - val_loss: 3.2140
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2266 - loss: 1.9421 - val_accuracy: 0.1000 - val_loss: 3.4597
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2162 - loss: 2.0260 - val_accuracy: 0.1303 - val_loss: 3.5931
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2109 - loss: 1.9296 - val_accuracy: 0.1086 - val_loss: 4.6419
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2557 - loss: 1.9616 - val_accuracy: 0.1698 - val_loss: 5.6369
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2266 - loss: 2.0603 - val_accuracy: 0.1546 - val_loss: 5.7211
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.2885 - loss: 1.8885 - val_accuracy: 0.1229 - val_loss: 66.4456
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2969 - loss: 1.7589 - val_accuracy: 0.1337 - val_loss: 57.1647
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2895 - loss: 1.8486 - val_accuracy: 0.1117 - val_loss: 91.9953
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2500 - loss: 1.7417 - val_accuracy: 0.1085 - val_loss: 105.6411
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3053 - loss: 1.8053 - val_accuracy: 0.1059 - val_loss: 298.8583
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2812 - loss: 1.7650 - val_accuracy: 0.1101 - val_loss: 369.8890
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3076 - loss: 1.7955 - val_accuracy: 0.1278 - val_loss: 391.7784
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3516 - loss: 1.8076 - val_accuracy: 0.1227 - val_loss: 436.4298
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3213 - loss: 1.8037 - val_accuracy: 0.1633 - val_loss: 277.6315
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1875 - loss: 1.8661 - val_accuracy: 0.1592 - val_loss: 229.1193
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3413 - loss: 1.7213 - val_accuracy: 0.1625 - val_loss: 193.2556
# Epoch 22/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2734 - loss: 1.7364 - val_accuracy: 0.1577 - val_loss: 216.6617
# Epoch 23/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3357 - loss: 1.7161 - val_accuracy: 0.1745 - val_loss: 164.0771
# Epoch 24/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3516 - loss: 1.6101 - val_accuracy: 0.1716 - val_loss: 164.2552
# Epoch 25/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3517 - loss: 1.7329 - val_accuracy: 0.1151 - val_loss: 441.5619
# Epoch 26/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3594 - loss: 1.7418 - val_accuracy: 0.1123 - val_loss: 439.9182
# Epoch 27/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3720 - loss: 1.6847 - val_accuracy: 0.1846 - val_loss: 183.1402
# Epoch 28/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3906 - loss: 1.6465 - val_accuracy: 0.1823 - val_loss: 178.4996
# Epoch 29/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3833 - loss: 1.6481 - val_accuracy: 0.1713 - val_loss: 308.9149
# Epoch 30/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4062 - loss: 1.5667 - val_accuracy: 0.1774 - val_loss: 281.4051
# Epoch 31/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3962 - loss: 1.6157 - val_accuracy: 0.1049 - val_loss: 365.4724
# Epoch 32/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3906 - loss: 1.6276 - val_accuracy: 0.1086 - val_loss: 344.2217
# Epoch 33/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4072 - loss: 1.6150 - val_accuracy: 0.1472 - val_loss: 432.7198
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4297 - loss: 1.5407 - val_accuracy: 0.1311 - val_loss: 458.4532
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4087 - loss: 1.6226 - val_accuracy: 0.1536 - val_loss: 701.3768
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3906 - loss: 1.7223 - val_accuracy: 0.1436 - val_loss: 751.0051
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4204 - loss: 1.6038 - val_accuracy: 0.1091 - val_loss: 758.4365
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4219 - loss: 1.5052 - val_accuracy: 0.1076 - val_loss: 777.9017
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4228 - loss: 1.5736 - val_accuracy: 0.1523 - val_loss: 502.3082
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4453 - loss: 1.5172 - val_accuracy: 0.1533 - val_loss: 492.9156
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4297 - loss: 1.5616 - val_accuracy: 0.1008 - val_loss: 1663.4694
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4219 - loss: 1.5675 - val_accuracy: 0.1013 - val_loss: 1721.3092
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.4435 - loss: 1.5486 - val_accuracy: 0.1121 - val_loss: 335.5112
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3594 - loss: 1.6008 - val_accuracy: 0.1102 - val_loss: 373.5205
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.4496 - loss: 1.5419 - val_accuracy: 0.1070 - val_loss: 523.0977
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4609 - loss: 1.4954 - val_accuracy: 0.1070 - val_loss: 529.0743
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4437 - loss: 1.5374 - val_accuracy: 0.1114 - val_loss: 761.2601
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4688 - loss: 1.4987 - val_accuracy: 0.1083 - val_loss: 748.7188
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4443 - loss: 1.5484 - val_accuracy: 0.1679 - val_loss: 111.2856
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4297 - loss: 1.5558 - val_accuracy: 0.1593 - val_loss: 117.5878
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4690 - loss: 1.5176 - val_accuracy: 0.1149 - val_loss: 405.1862
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4688 - loss: 1.4468 - val_accuracy: 0.1178 - val_loss: 394.3955
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4682 - loss: 1.5265 - val_accuracy: 0.1484 - val_loss: 387.1035
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4922 - loss: 1.4042 - val_accuracy: 0.1428 - val_loss: 396.1509
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4656 - loss: 1.5088 - val_accuracy: 0.1196 - val_loss: 648.0876
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4844 - loss: 1.5499 - val_accuracy: 0.1276 - val_loss: 611.0587
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4412 - loss: 1.5889 - val_accuracy: 0.1001 - val_loss: 376.5702
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4141 - loss: 1.5987 - val_accuracy: 0.1001 - val_loss: 447.2752
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3873 - loss: 1.6703 - val_accuracy: 0.1867 - val_loss: 62.9369
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5547 - loss: 1.4748 - val_accuracy: 0.1870 - val_loss: 54.5188
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_80 (Conv2D)                   │ (None, 16, 16, 48)          │           1,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_48 (MaxPooling2D)      │ (None, 8, 8, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_48               │ (None, 8, 8, 48)            │             192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_81 (Conv2D)                   │ (None, 8, 8, 96)            │          41,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_49 (MaxPooling2D)      │ (None, 3, 3, 96)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_49               │ (None, 3, 3, 96)            │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_82 (Conv2D)                   │ (None, 3, 3, 192)           │         166,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_83 (Conv2D)                   │ (None, 3, 3, 192)           │         331,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_84 (Conv2D)                   │ (None, 3, 3, 256)           │         442,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_50 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_50               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_16 (Flatten)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_48 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_32 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_33 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_50 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.1369 - loss: 2.7171 - val_accuracy: 0.1000 - val_loss: 9.5676
# Epoch 2/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1250 - loss: 2.1167 - val_accuracy: 0.1000 - val_loss: 10.1216
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.1864 - loss: 2.1466 - val_accuracy: 0.1095 - val_loss: 4.3765
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2031 - loss: 2.0500 - val_accuracy: 0.0997 - val_loss: 10.4576
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2073 - loss: 2.0690 - val_accuracy: 0.1000 - val_loss: 122.1848
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2109 - loss: 2.1655 - val_accuracy: 0.1000 - val_loss: 95.0314
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2343 - loss: 2.0307 - val_accuracy: 0.1000 - val_loss: 114.1945
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2422 - loss: 2.0195 - val_accuracy: 0.1000 - val_loss: 110.9766
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2578 - loss: 1.9132 - val_accuracy: 0.0999 - val_loss: 84.2605
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2578 - loss: 1.9224 - val_accuracy: 0.1032 - val_loss: 79.8230
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2691 - loss: 1.8790 - val_accuracy: 0.1058 - val_loss: 101.8385
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2812 - loss: 1.7869 - val_accuracy: 0.0998 - val_loss: 126.6785
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2834 - loss: 1.8337 - val_accuracy: 0.1000 - val_loss: 281.8084
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2578 - loss: 1.9343 - val_accuracy: 0.1000 - val_loss: 278.2611
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2829 - loss: 1.8386 - val_accuracy: 0.1000 - val_loss: 455.2054
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3359 - loss: 1.7575 - val_accuracy: 0.1000 - val_loss: 472.2337
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3090 - loss: 1.7996 - val_accuracy: 0.1000 - val_loss: 1101.2787
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2812 - loss: 1.8720 - val_accuracy: 0.1000 - val_loss: 1173.0405
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3185 - loss: 1.7923 - val_accuracy: 0.1000 - val_loss: 777.3564
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3516 - loss: 1.7309 - val_accuracy: 0.1000 - val_loss: 789.6102
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3199 - loss: 1.7722 - val_accuracy: 0.1000 - val_loss: 758.3959
# Epoch 22/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3281 - loss: 1.7417 - val_accuracy: 0.1000 - val_loss: 652.9324
# Epoch 23/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3290 - loss: 1.7385 - val_accuracy: 0.1000 - val_loss: 211.1695
# Epoch 24/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3281 - loss: 1.7911 - val_accuracy: 0.1000 - val_loss: 213.5523
# Epoch 25/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3106 - loss: 1.8078 - val_accuracy: 0.1000 - val_loss: 772.9315
# Epoch 26/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3438 - loss: 1.7449 - val_accuracy: 0.1000 - val_loss: 858.3188
# Epoch 27/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3228 - loss: 1.7717 - val_accuracy: 0.1300 - val_loss: 229.9758
# Epoch 28/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2969 - loss: 1.7771 - val_accuracy: 0.1341 - val_loss: 208.6394
# Epoch 29/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3318 - loss: 1.7813 - val_accuracy: 0.1016 - val_loss: 330.4061
# Epoch 30/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3594 - loss: 1.6946 - val_accuracy: 0.1013 - val_loss: 324.0709
# Epoch 31/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3535 - loss: 1.6956 - val_accuracy: 0.1416 - val_loss: 148.3329
# Epoch 32/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3594 - loss: 1.6998 - val_accuracy: 0.1320 - val_loss: 160.9329
# Epoch 33/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3475 - loss: 1.6974 - val_accuracy: 0.1195 - val_loss: 347.1680
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3281 - loss: 1.6903 - val_accuracy: 0.1168 - val_loss: 324.9581
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3641 - loss: 1.6673 - val_accuracy: 0.1905 - val_loss: 78.0393
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3594 - loss: 1.6993 - val_accuracy: 0.1790 - val_loss: 84.4099
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3637 - loss: 1.7190 - val_accuracy: 0.1365 - val_loss: 243.7224
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2812 - loss: 1.7409 - val_accuracy: 0.1390 - val_loss: 237.3106
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3763 - loss: 1.6777 - val_accuracy: 0.1433 - val_loss: 206.4862
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3359 - loss: 1.6634 - val_accuracy: 0.1392 - val_loss: 229.2241
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3822 - loss: 1.6506 - val_accuracy: 0.1148 - val_loss: 117.2824
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3906 - loss: 1.6547 - val_accuracy: 0.1094 - val_loss: 168.2682
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3884 - loss: 1.6513 - val_accuracy: 0.1233 - val_loss: 36.8582
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4531 - loss: 1.5360 - val_accuracy: 0.1317 - val_loss: 22.7789
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3939 - loss: 1.6419 - val_accuracy: 0.1560 - val_loss: 75.2716
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4297 - loss: 1.5255 - val_accuracy: 0.1707 - val_loss: 72.4275
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4107 - loss: 1.6050 - val_accuracy: 0.1391 - val_loss: 58.7365
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3984 - loss: 1.7028 - val_accuracy: 0.1375 - val_loss: 75.1622
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4248 - loss: 1.5791 - val_accuracy: 0.1341 - val_loss: 13.2334
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2109 - loss: 1.9573 - val_accuracy: 0.1264 - val_loss: 15.0161
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2375 - loss: 2.0421 - val_accuracy: 0.1006 - val_loss: 278.4365
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2734 - loss: 1.8741 - val_accuracy: 0.1004 - val_loss: 389.8227
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2888 - loss: 1.8887 - val_accuracy: 0.1213 - val_loss: 103.6776
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3438 - loss: 1.7943 - val_accuracy: 0.1169 - val_loss: 135.1977
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3292 - loss: 1.8140 - val_accuracy: 0.1271 - val_loss: 287.1205
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3672 - loss: 1.6907 - val_accuracy: 0.1279 - val_loss: 301.3967
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3305 - loss: 1.7827 - val_accuracy: 0.1296 - val_loss: 131.9865
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3750 - loss: 1.6246 - val_accuracy: 0.1386 - val_loss: 131.0523
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3768 - loss: 1.7046 - val_accuracy: 0.1003 - val_loss: 485.3218
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3594 - loss: 1.6972 - val_accuracy: 0.1002 - val_loss: 472.6772
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_85 (Conv2D)                   │ (None, 16, 16, 48)          │           1,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_51 (MaxPooling2D)      │ (None, 8, 8, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_51               │ (None, 8, 8, 48)            │             192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_86 (Conv2D)                   │ (None, 8, 8, 96)            │          41,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_52 (MaxPooling2D)      │ (None, 3, 3, 96)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_52               │ (None, 3, 3, 96)            │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_87 (Conv2D)                   │ (None, 3, 3, 192)           │         166,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_88 (Conv2D)                   │ (None, 3, 3, 192)           │         331,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_89 (Conv2D)                   │ (None, 3, 3, 256)           │         442,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_53 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_53               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_17 (Flatten)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_51 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_34 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_52 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_35 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_53 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.1280 - loss: 2.7337 - val_accuracy: 0.1000 - val_loss: 6.1613
# Epoch 2/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1406 - loss: 2.2357 - val_accuracy: 0.1000 - val_loss: 6.5497
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.1436 - loss: 2.2189 - val_accuracy: 0.1000 - val_loss: 9.5665
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2500 - loss: 2.0164 - val_accuracy: 0.1000 - val_loss: 11.0681
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.1717 - loss: 2.1644 - val_accuracy: 0.1011 - val_loss: 5.1553
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1797 - loss: 2.2022 - val_accuracy: 0.1015 - val_loss: 5.4221
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.1795 - loss: 2.1353 - val_accuracy: 0.1000 - val_loss: 10.0407
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1250 - loss: 2.1156 - val_accuracy: 0.1000 - val_loss: 17.5943
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2056 - loss: 2.0701 - val_accuracy: 0.1002 - val_loss: 229.0883
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1875 - loss: 2.1508 - val_accuracy: 0.1031 - val_loss: 222.5761
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2099 - loss: 2.0137 - val_accuracy: 0.1000 - val_loss: 279.2235
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1562 - loss: 2.0075 - val_accuracy: 0.1000 - val_loss: 253.3103
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.2104 - loss: 2.0050 - val_accuracy: 0.1193 - val_loss: 243.4055
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2188 - loss: 1.9574 - val_accuracy: 0.1303 - val_loss: 260.6783
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2467 - loss: 1.9219 - val_accuracy: 0.1075 - val_loss: 143.7962
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2969 - loss: 1.8508 - val_accuracy: 0.1132 - val_loss: 125.9514
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.2538 - loss: 1.9028 - val_accuracy: 0.0998 - val_loss: 211.6774
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2969 - loss: 1.7766 - val_accuracy: 0.0999 - val_loss: 196.4067
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2727 - loss: 1.8782 - val_accuracy: 0.1061 - val_loss: 243.2854
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2578 - loss: 1.7676 - val_accuracy: 0.1160 - val_loss: 220.7432
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.2676 - loss: 1.8617 - val_accuracy: 0.1346 - val_loss: 281.4062
# Epoch 22/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3125 - loss: 1.7925 - val_accuracy: 0.1524 - val_loss: 220.3820
# Epoch 23/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2791 - loss: 1.8585 - val_accuracy: 0.1018 - val_loss: 506.8881
# Epoch 24/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3359 - loss: 1.6918 - val_accuracy: 0.1018 - val_loss: 502.2427
# Epoch 25/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2930 - loss: 1.8272 - val_accuracy: 0.1217 - val_loss: 714.1824
# Epoch 26/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2734 - loss: 1.8434 - val_accuracy: 0.1205 - val_loss: 654.9169
# Epoch 27/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2865 - loss: 1.8398 - val_accuracy: 0.1006 - val_loss: 1001.4543
# Epoch 28/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3438 - loss: 1.7102 - val_accuracy: 0.1020 - val_loss: 1042.5150
# Epoch 29/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2988 - loss: 1.7916 - val_accuracy: 0.1141 - val_loss: 766.6007
# Epoch 30/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3281 - loss: 1.6913 - val_accuracy: 0.1163 - val_loss: 801.5756
# Epoch 31/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3158 - loss: 1.7652 - val_accuracy: 0.1243 - val_loss: 1197.8767
# Epoch 32/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3281 - loss: 1.8016 - val_accuracy: 0.1195 - val_loss: 1239.3326
# Epoch 33/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3223 - loss: 1.7767 - val_accuracy: 0.1041 - val_loss: 843.4873
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3594 - loss: 1.6848 - val_accuracy: 0.1017 - val_loss: 1008.9630
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3294 - loss: 1.7158 - val_accuracy: 0.1665 - val_loss: 13.6637
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4141 - loss: 1.6466 - val_accuracy: 0.1428 - val_loss: 3.6589
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3327 - loss: 1.7214 - val_accuracy: 0.1058 - val_loss: 599.1030
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2266 - loss: 1.8795 - val_accuracy: 0.1023 - val_loss: 641.7634
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3154 - loss: 1.7735 - val_accuracy: 0.1354 - val_loss: 805.6091
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3281 - loss: 2.0406 - val_accuracy: 0.1257 - val_loss: 744.5734
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3228 - loss: 1.7470 - val_accuracy: 0.1548 - val_loss: 627.9888
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3203 - loss: 1.7428 - val_accuracy: 0.1472 - val_loss: 677.9240
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3487 - loss: 1.7170 - val_accuracy: 0.1647 - val_loss: 617.2582
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3906 - loss: 1.7356 - val_accuracy: 0.1753 - val_loss: 614.6766
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3503 - loss: 1.7160 - val_accuracy: 0.1907 - val_loss: 710.7056
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3906 - loss: 1.5916 - val_accuracy: 0.1833 - val_loss: 706.4595
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3651 - loss: 1.6829 - val_accuracy: 0.1111 - val_loss: 511.6046
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4141 - loss: 1.6903 - val_accuracy: 0.1051 - val_loss: 595.8752
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.3601 - loss: 1.6658 - val_accuracy: 0.1244 - val_loss: 254.9137
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3750 - loss: 1.5912 - val_accuracy: 0.1261 - val_loss: 243.2445
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3787 - loss: 1.6480 - val_accuracy: 0.1699 - val_loss: 294.1256
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3516 - loss: 1.6473 - val_accuracy: 0.1697 - val_loss: 296.7924
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3777 - loss: 1.6492 - val_accuracy: 0.1901 - val_loss: 158.7182
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4766 - loss: 1.4296 - val_accuracy: 0.1864 - val_loss: 153.0722
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3884 - loss: 1.6162 - val_accuracy: 0.1746 - val_loss: 493.0894
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3281 - loss: 1.7284 - val_accuracy: 0.1778 - val_loss: 481.8765
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3976 - loss: 1.6214 - val_accuracy: 0.2327 - val_loss: 142.6945
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4297 - loss: 1.5319 - val_accuracy: 0.2320 - val_loss: 150.6332
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4016 - loss: 1.6168 - val_accuracy: 0.1203 - val_loss: 339.0883
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4844 - loss: 1.4837 - val_accuracy: 0.1243 - val_loss: 293.6003
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_90 (Conv2D)                   │ (None, 16, 16, 48)          │           1,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_54 (MaxPooling2D)      │ (None, 8, 8, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_54               │ (None, 8, 8, 48)            │             192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_91 (Conv2D)                   │ (None, 8, 8, 96)            │          41,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_55 (MaxPooling2D)      │ (None, 3, 3, 96)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_55               │ (None, 3, 3, 96)            │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_92 (Conv2D)                   │ (None, 3, 3, 192)           │         166,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_93 (Conv2D)                   │ (None, 3, 3, 192)           │         331,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_94 (Conv2D)                   │ (None, 3, 3, 256)           │         442,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_56 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_56               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_18 (Flatten)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_54 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_36 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_55 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_37 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_56 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.1220 - loss: 2.8320 - val_accuracy: 0.1000 - val_loss: 2.3058
# Epoch 2/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1953 - loss: 2.1770 - val_accuracy: 0.1000 - val_loss: 2.3059
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.1659 - loss: 2.1579 - val_accuracy: 0.1000 - val_loss: 2.3124
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2578 - loss: 2.0385 - val_accuracy: 0.1000 - val_loss: 2.3126
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.1856 - loss: 2.0816 - val_accuracy: 0.1000 - val_loss: 2.3144
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1875 - loss: 2.0528 - val_accuracy: 0.1000 - val_loss: 2.3144
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2066 - loss: 2.0170 - val_accuracy: 0.1000 - val_loss: 11.3061
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2578 - loss: 1.8971 - val_accuracy: 0.1000 - val_loss: 11.1772
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2566 - loss: 1.9536 - val_accuracy: 0.1000 - val_loss: 99.3518
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2578 - loss: 1.9427 - val_accuracy: 0.1000 - val_loss: 74.6130
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.2775 - loss: 1.8979 - val_accuracy: 0.0992 - val_loss: 64.1191
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3203 - loss: 1.8654 - val_accuracy: 0.0994 - val_loss: 78.9010
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2855 - loss: 1.8265 - val_accuracy: 0.1035 - val_loss: 7.3088
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3359 - loss: 1.7340 - val_accuracy: 0.1033 - val_loss: 7.8285
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2936 - loss: 1.8093 - val_accuracy: 0.1000 - val_loss: 1336.9053
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2969 - loss: 2.0175 - val_accuracy: 0.1000 - val_loss: 1173.7487
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2642 - loss: 1.9102 - val_accuracy: 0.1120 - val_loss: 71.8005
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3125 - loss: 1.8863 - val_accuracy: 0.1176 - val_loss: 70.4082
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3121 - loss: 1.7920 - val_accuracy: 0.1151 - val_loss: 67.4030
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2656 - loss: 1.8774 - val_accuracy: 0.1119 - val_loss: 60.8309
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3077 - loss: 1.7630 - val_accuracy: 0.1021 - val_loss: 92.0225
# Epoch 22/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3828 - loss: 1.6229 - val_accuracy: 0.1063 - val_loss: 87.5638
# Epoch 23/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3182 - loss: 1.7463 - val_accuracy: 0.1235 - val_loss: 48.5692
# Epoch 24/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3594 - loss: 1.8009 - val_accuracy: 0.1255 - val_loss: 54.4312
# Epoch 25/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3214 - loss: 1.7301 - val_accuracy: 0.1130 - val_loss: 114.5346
# Epoch 26/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3828 - loss: 1.6723 - val_accuracy: 0.1210 - val_loss: 121.5817
# Epoch 27/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3418 - loss: 1.6882 - val_accuracy: 0.1299 - val_loss: 89.4661
# Epoch 28/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3594 - loss: 1.7615 - val_accuracy: 0.1300 - val_loss: 100.4793
# Epoch 29/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3486 - loss: 1.6758 - val_accuracy: 0.1389 - val_loss: 29.6742
# Epoch 30/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3281 - loss: 1.6382 - val_accuracy: 0.1497 - val_loss: 23.2690
# Epoch 31/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3558 - loss: 1.6729 - val_accuracy: 0.1152 - val_loss: 92.0500
# Epoch 32/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2969 - loss: 1.7042 - val_accuracy: 0.1129 - val_loss: 115.2426
# Epoch 33/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.3461 - loss: 1.6820 - val_accuracy: 0.1007 - val_loss: 157.2240
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2500 - loss: 1.8493 - val_accuracy: 0.1010 - val_loss: 147.0067
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3607 - loss: 1.6647 - val_accuracy: 0.0970 - val_loss: 80.0947
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2266 - loss: 2.0758 - val_accuracy: 0.1005 - val_loss: 3.7481
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.2301 - loss: 2.0102 - val_accuracy: 0.1000 - val_loss: 824.2094
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2578 - loss: 1.8733 - val_accuracy: 0.1027 - val_loss: 786.7922
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3132 - loss: 1.8024 - val_accuracy: 0.1274 - val_loss: 94.6112
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3750 - loss: 1.6484 - val_accuracy: 0.1293 - val_loss: 52.9852
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3333 - loss: 1.7504 - val_accuracy: 0.0987 - val_loss: 198.5356
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3438 - loss: 1.6631 - val_accuracy: 0.0991 - val_loss: 223.8318
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3374 - loss: 1.7523 - val_accuracy: 0.1000 - val_loss: 934.9055
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3828 - loss: 1.7367 - val_accuracy: 0.1000 - val_loss: 889.6050
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3428 - loss: 1.7230 - val_accuracy: 0.1012 - val_loss: 557.0625
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3125 - loss: 1.7614 - val_accuracy: 0.1011 - val_loss: 539.2979
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3887 - loss: 1.6553 - val_accuracy: 0.1161 - val_loss: 655.5367
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3672 - loss: 1.7027 - val_accuracy: 0.1394 - val_loss: 717.9909
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3643 - loss: 1.6410 - val_accuracy: 0.1004 - val_loss: 728.4160
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3359 - loss: 1.6806 - val_accuracy: 0.1005 - val_loss: 760.2894
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3952 - loss: 1.6184 - val_accuracy: 0.1639 - val_loss: 38.8942
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3438 - loss: 1.6501 - val_accuracy: 0.1636 - val_loss: 51.8103
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3953 - loss: 1.6267 - val_accuracy: 0.1559 - val_loss: 599.8550
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5000 - loss: 1.4166 - val_accuracy: 0.1569 - val_loss: 647.7349
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4121 - loss: 1.5737 - val_accuracy: 0.1229 - val_loss: 508.5016
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3125 - loss: 2.5833 - val_accuracy: 0.1652 - val_loss: 433.1392
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4036 - loss: 1.6116 - val_accuracy: 0.1497 - val_loss: 482.4852
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3750 - loss: 1.7417 - val_accuracy: 0.1406 - val_loss: 581.7113
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.4094 - loss: 1.5957 - val_accuracy: 0.1481 - val_loss: 796.3878
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4531 - loss: 1.4741 - val_accuracy: 0.1476 - val_loss: 830.1838

# %%
import os

save_dir = "models"
os.makedirs(save_dir, exist_ok = True)

for i in range(0, n):
    
    model = globals()[f'model{i}']
    
    model_path = os.path.join(save_dir, f'model_{i}.h5')
    model.save(model_path)
    print(f"Saved model {i} to {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model 0 to models\model_0.h5
# Saved model 1 to models\model_1.h5
# Saved model 2 to models\model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model 3 to models\model_3.h5
# Saved model 4 to models\model_4.h5
