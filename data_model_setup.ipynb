# %%
import os

import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

from collections import Counter

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# %%
# for i in range(n):
#     for prefix in ['x_train_split', 'y_train_split', 'y_onehot', 'index_split', 'model', 'history']:
#         var_name = f'{prefix}{i}'
#         if var_name in globals():
#             del globals()[var_name]

# %%
optimizer = "Adam"
loss_function = "categorical_crossentropy"
epochs = 60
batch_size = 128
learning_rate = .01
img_width = 32
img_height = 32
n = 5
num_class = 10
input_shape = (img_width, img_height, 3)
steps_per_epoch = 10000 // batch_size

# %%
#load CIFAR-10 DATA
def load_data():
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    
    #normalize pixel values to 0-1 to simplify training
    x_train = x_train.astype("float32") / 255.0
    x_test = x_test.astype("float32") / 255.0
    
    #flatten and encode labels
    y_train = y_train.flatten()
    y_test =  y_test.flatten()
    
    # y_train = to_categorical(y_train)
    # y_test = to_categorical(y_test)
    
    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = load_data()

# %%
#AlexNet Model setup - includes matching parameters with MIAShield
def create_model(input_shape, num_class):
    model = Sequential()

    #Layer 1 - Conv2D with MaxPooling
    model.add(Conv2D(48, (3, 3), strides = (2, 2), activation = "relu", padding = "same", input_shape = input_shape))
    model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
    model.add(BatchNormalization())

    #Layer 2 - Conv2D with MaxPooling 
    model.add(Conv2D(96, (3, 3), activation = "relu", padding = "same"))
    model.add(MaxPooling2D(pool_size = (3, 3), strides = (2, 2)))
    model.add(BatchNormalization())

    #Layer 3 - Conv2D
    model.add(Conv2D(192, (3, 3), activation = "relu", padding = "same"))

    #Layer 4 - Conv2D
    model.add(Conv2D(192, (3, 3), activation = "relu", padding = "same"))

    #Layer 5 - Conv2D with MaxPooling
    model.add(Conv2D(256, (3, 3), activation = "relu", padding = "same"))
    model.add(MaxPooling2D(pool_size = (3, 3), strides = (2, 2)))
    model.add(BatchNormalization())

    #flatten
    model.add(Flatten())

    #Fully Connected layer 1
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(.50))
            
    #Fully Connected layer 2
    model.add(Dense(256, activation = "relu"))
    model.add(Dropout(.50))

    #Output layer
    model.add(Dense(num_class, activation = "softmax"))

    return model

# %%
X = x_train
Y = y_train
idx = np.arange(len(X))

skf = StratifiedKFold(n_splits = n, shuffle = True, random_state = 42)
skf.get_n_splits(X, Y)
    
for i, (_, test_index) in enumerate(skf.split(X,Y)):
    Xi = X[test_index]
    Yi = Y[test_index]
    Y_onehot = to_categorical(Yi, num_classes = num_class)
    index_split = idx[test_index]
    
    globals()[f'x_train_split{i}'] = Xi
    globals()[f'y_train_split{i}'] = Yi
    globals()[f'y_onehot{i}'] = Y_onehot
    globals()[f'index_split{i}'] = index_split

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range = 10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range = .2,
    zoom_range=0.2,
    horizontal_flip=True,
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# train_generator = train_datagen.flow(
#     x_,
#     target_size=(img_width, img_height),
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# val_generator = val_datagen.flow_from_directory(
#     y_test,
#     target_size=(img_width, img_height),
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# %%
#recombine indices from across all splits
all_indices = np.concatenate([globals()[f'index_split{i}'] for i in range(n)])
print(f"Total number of indices: {len(all_indices)}")

# check for duplicate values to ensure disjointedness
has_duplicates = len(all_indices) != len(np.unique(all_indices))
print("Duplicate Indices Present:", has_duplicates)

# check to ensure full dataset is represented
covers_all = len(all_indices) == len(X)
print("Coverage of Dataset Achieved:", covers_all)
# Out:
# Total number of indices: 50000
# Duplicate Indices Present: False
# Coverage of Dataset Achieved: True

# %%
#verify that label distribution is consistent across all data partitions
for i in range(n):
    labels = globals()[f'y_train_split{i}']
    counts = Counter(labels)
    print(f"Fold {i} label distribution:", dict(counts))
# Out:
# Fold 0 label distribution: {7: 1000, 9: 1000, 4: 1000, 6: 1000, 5: 1000, 0: 1000, 3: 1000, 2: 1000, 1: 1000, 8: 1000}
# Fold 1 label distribution: {6: 1000, 9: 1000, 4: 1000, 8: 1000, 7: 1000, 1: 1000, 5: 1000, 3: 1000, 0: 1000, 2: 1000}
# Fold 2 label distribution: {9: 1000, 1: 1000, 3: 1000, 6: 1000, 4: 1000, 7: 1000, 2: 1000, 0: 1000, 8: 1000, 5: 1000}
# Fold 3 label distribution: {1: 1000, 2: 1000, 3: 1000, 4: 1000, 0: 1000, 9: 1000, 5: 1000, 8: 1000, 6: 1000, 7: 1000}
# Fold 4 label distribution: {7: 1000, 2: 1000, 0: 1000, 9: 1000, 3: 1000, 1: 1000, 8: 1000, 5: 1000, 4: 1000, 6: 1000}

# %%
for i in range(0, n):
    trained_model = create_model(input_shape, num_class)
    optimizer = tf.keras.optimizers.Adam(learning_rate=.01)
    loss_function = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    trained_model.compile(optimizer = optimizer, loss = loss_function, metrics = ['accuracy'])
    trained_model.summary()
    model_data = globals()[f'x_train_split{i}']
    target_data = globals()[f'y_train_split{i}']
    print(target_data.shape)
    datagen = train_datagen

    globals()[f'history{i}'] = trained_model.fit(datagen.flow(model_data, target_data, batch_size=128, shuffle=False),
                    steps_per_epoch = steps_per_epoch, epochs=epochs, validation_data=(x_test, y_test))
    globals()[f'model{i}'] = trained_model
# Out:
# C:\Users\Owner\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_115 (Conv2D)             │ (None, 16, 16, 48)     │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_69 (MaxPooling2D) │ (None, 8, 8, 48)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_69          │ (None, 8, 8, 48)       │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_116 (Conv2D)             │ (None, 8, 8, 96)       │        41,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_70 (MaxPooling2D) │ (None, 3, 3, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_70          │ (None, 3, 3, 96)       │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_117 (Conv2D)             │ (None, 3, 3, 192)      │       166,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_118 (Conv2D)             │ (None, 3, 3, 192)      │       331,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_119 (Conv2D)             │ (None, 3, 3, 256)      │       442,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_71 (MaxPooling2D) │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_71          │ (None, 1, 1, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_23 (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1

# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_130 (Conv2D)             │ (None, 16, 16, 48)     │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_78 (MaxPooling2D) │ (None, 8, 8, 48)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_78          │ (None, 8, 8, 48)       │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_131 (Conv2D)             │ (None, 8, 8, 96)       │        41,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_79 (MaxPooling2D) │ (None, 3, 3, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_79          │ (None, 3, 3, 96)       │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_132 (Conv2D)             │ (None, 3, 3, 192)      │       166,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_133 (Conv2D)             │ (None, 3, 3, 192)      │       331,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_134 (Conv2D)             │ (None, 3, 3, 256)      │       442,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_80 (MaxPooling2D) │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_80          │ (None, 1, 1, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_26 (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_53 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_80 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.1033 - loss: 2.6787 - val_accuracy: 0.1000 - val_loss: 2.3042
# Epoch 2/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0859 - loss: 2.3077 - val_accuracy: 0.1000 - val_loss: 2.3043
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.1288 - loss: 2.2666 - val_accuracy: 0.1000 - val_loss: 2.3114
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0938 - loss: 2.2209 - val_accuracy: 0.1000 - val_loss: 2.3116
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.1548 - loss: 2.2038 - val_accuracy: 0.1000 - val_loss: 2.3377
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1641 - loss: 2.2386 - val_accuracy: 0.1000 - val_loss: 2.3378
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.1525 - loss: 2.1813 - val_accuracy: 0.1547 - val_loss: 2.5338
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.1641 - loss: 2.2505 - val_accuracy: 0.1160 - val_loss: 2.3260
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.1620 - loss: 2.1097 - val_accuracy: 0.1778 - val_loss: 7.1719
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1328 - loss: 2.2013 - val_accuracy: 0.1775 - val_loss: 7.0536
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.1811 - loss: 2.0905 - val_accuracy: 0.1764 - val_loss: 12.7334
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1875 - loss: 2.0506 - val_accuracy: 0.1736 - val_loss: 16.4073
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.1738 - loss: 2.0562 - val_accuracy: 0.1002 - val_loss: 388.7898
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1562 - loss: 2.1340 - val_accuracy: 0.1040 - val_loss: 392.8834
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.1709 - loss: 2.0639 - val_accuracy: 0.1642 - val_loss: 70.7756
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2266 - loss: 2.0492 - val_accuracy: 0.1553 - val_loss: 82.5078
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.1945 - loss: 2.0291 - val_accuracy: 0.1233 - val_loss: 202.2084
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1797 - loss: 2.0704 - val_accuracy: 0.1319 - val_loss: 190.0786
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.1841 - loss: 2.0587 - val_accuracy: 0.1023 - val_loss: 109.8536
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2109 - loss: 2.0553 - val_accuracy: 0.1020 - val_loss: 106.1114
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s
60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.2556 - loss: 1.8724 - val_accuracy: 0.1211 - val_loss: 307.0083
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2812 - loss: 1.9218 - val_accuracy: 0.1263 - val_loss: 285.2751
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2650 - loss: 1.8628 - val_accuracy: 0.1343 - val_loss: 1151.8883
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2500 - loss: 1.9432 - val_accuracy: 0.1359 - val_loss: 1170.9792
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.2716 - loss: 1.8506 - val_accuracy: 0.1562 - val_loss: 91.4598
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2969 - loss: 1.8600 - val_accuracy: 0.1504 - val_loss: 101.0563
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2860 - loss: 1.8365 - val_accuracy: 0.1140 - val_loss: 415.8684
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2656 - loss: 1.8450 - val_accuracy: 0.1140 - val_loss: 392.2061
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.2802 - loss: 1.8374 - val_accuracy: 0.1470 - val_loss: 154.3411
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2578 - loss: 1.9978 - val_accuracy: 0.1419 - val_loss: 166.0378
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2931 - loss: 1.8349 - val_accuracy: 0.1419 - val_loss: 95.2922
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2812 - loss: 1.6731 - val_accuracy: 0.1454 - val_loss: 106.2157
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_135 (Conv2D)             │ (None, 16, 16, 48)     │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_81 (MaxPooling2D) │ (None, 8, 8, 48)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_81          │ (None, 8, 8, 48)       │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_136 (Conv2D)             │ (None, 8, 8, 96)       │        41,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_82 (MaxPooling2D) │ (None, 3, 3, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_82          │ (None, 3, 3, 96)       │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_137 (Conv2D)             │ (None, 3, 3, 192)      │       166,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_138 (Conv2D)             │ (None, 3, 3, 192)      │       331,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_139 (Conv2D)             │ (None, 3, 3, 256)      │       442,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_83 (MaxPooling2D) │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_83          │ (None, 1, 1, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_27 (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_81 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_54 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_55 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,250,666 (4.77 MB)
#  Trainable params: 1,249,866 (4.77 MB)
#  Non-trainable params: 800 (3.12 KB)
# (10000,)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.1233 - loss: 2.7756 - val_accuracy: 0.1000 - val_loss: 2.3042
# Epoch 2/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1562 - loss: 2.2961 - val_accuracy: 0.1000 - val_loss: 2.3042
# Epoch 3/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.1348 - loss: 2.2509 - val_accuracy: 0.1000 - val_loss: 2.3037
# Epoch 4/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1406 - loss: 2.2287 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 5/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.1728 - loss: 2.1530 - val_accuracy: 0.1000 - val_loss: 8.3861
# Epoch 6/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1328 - loss: 2.1408 - val_accuracy: 0.1014 - val_loss: 3.6581
# Epoch 7/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.1839 - loss: 2.0985 - val_accuracy: 0.1000 - val_loss: 2.3055
# Epoch 8/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2031 - loss: 2.0986 - val_accuracy: 0.1000 - val_loss: 2.3056
# Epoch 9/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.2043 - loss: 2.0412 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 10/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2500 - loss: 1.9268 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 11/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.2511 - loss: 1.9310 - val_accuracy: 0.1000 - val_loss: 424.6886
# Epoch 12/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3125 - loss: 1.7302 - val_accuracy: 0.1000 - val_loss: 499.9152
# Epoch 13/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.2614 - loss: 1.8894 - val_accuracy: 0.1000 - val_loss: 2.6997
# Epoch 14/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2734 - loss: 1.7362 - val_accuracy: 0.1000 - val_loss: 2.7392
# Epoch 15/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.2909 - loss: 1.8336 - val_accuracy: 0.1000 - val_loss: 2.5798
# Epoch 16/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2578 - loss: 1.8691 - val_accuracy: 0.1000 - val_loss: 2.5013
# Epoch 17/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.2900 - loss: 1.8353 - val_accuracy: 0.1000 - val_loss: 2.6752
# Epoch 18/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2891 - loss: 1.7487 - val_accuracy: 0.1000 - val_loss: 2.6103
# Epoch 19/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.3116 - loss: 1.8126 - val_accuracy: 0.1000 - val_loss: 2.3078
# Epoch 20/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3594 - loss: 1.6927 - val_accuracy: 0.1000 - val_loss: 2.3078
# Epoch 21/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3184 - loss: 1.7671 - val_accuracy: 0.1000 - val_loss: 2.3084
# Epoch 22/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3125 - loss: 1.9018 - val_accuracy: 0.1000 - val_loss: 2.3084
# Epoch 23/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3102 - loss: 1.7877 - val_accuracy: 0.0958 - val_loss: 52.4391
# Epoch 24/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3594 - loss: 1.8380 - val_accuracy: 0.0901 - val_loss: 97.6965
# Epoch 25/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3212 - loss: 1.7697 - val_accuracy: 0.0939 - val_loss: 10987.7061
# Epoch 26/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4609 - loss: 1.6613 - val_accuracy: 0.0927 - val_loss: 10999.1260
# Epoch 27/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.3300 - loss: 1.7325 - val_accuracy: 0.1000 - val_loss: 2.3155
# Epoch 28/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3672 - loss: 1.7180 - val_accuracy: 0.1000 - val_loss: 2.3155
# Epoch 29/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3491 - loss: 1.7162 - val_accuracy: 0.1023 - val_loss: 41.6515
# Epoch 30/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3203 - loss: 1.6672 - val_accuracy: 0.1016 - val_loss: 31.4706
# Epoch 31/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3403 - loss: 1.6998 - val_accuracy: 0.1000 - val_loss: 6.6415
# Epoch 32/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3203 - loss: 1.7885 - val_accuracy: 0.1000 - val_loss: 4.1511
# Epoch 33/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.3493 - loss: 1.6880 - val_accuracy: 0.1001 - val_loss: 2.8163
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3516 - loss: 1.5592 - val_accuracy: 0.1006 - val_loss: 13.5523
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.3377 - loss: 1.7019 - val_accuracy: 0.1000 - val_loss: 2.3200
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.2578 - loss: 1.8967 - val_accuracy: 0.1000 - val_loss: 2.3200
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3383 - loss: 1.6919 - val_accuracy: 0.1002 - val_loss: 6851.1465
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3203 - loss: 1.7968 - val_accuracy: 0.1002 - val_loss: 6323.2593
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3419 - loss: 1.7048 - val_accuracy: 0.1001 - val_loss: 3245.8740
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3359 - loss: 1.7032 - val_accuracy: 0.1000 - val_loss: 3389.5413
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3436 - loss: 1.7011 - val_accuracy: 0.1000 - val_loss: 3804.0017
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3516 - loss: 1.6112 - val_accuracy: 0.1000 - val_loss: 3856.0525
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.3551 - loss: 1.6714 - val_accuracy: 0.1000 - val_loss: 2736.3762
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3594 - loss: 1.6068 - val_accuracy: 0.1001 - val_loss: 2726.8384
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.3564 - loss: 1.6641 - val_accuracy: 0.1004 - val_loss: 2473.7395
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3750 - loss: 1.5877 - val_accuracy: 0.1005 - val_loss: 2444.1040
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3698 - loss: 1.6347 - val_accuracy: 0.1095 - val_loss: 1236.7760
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4062 - loss: 1.5106 - val_accuracy: 0.1040 - val_loss: 1340.2382
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.3680 - loss: 1.6336 - val_accuracy: 0.1000 - val_loss: 1350.0017
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4141 - loss: 1.5873 - val_accuracy: 0.1018 - val_loss: 1360.5326
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.3879 - loss: 1.6180 - val_accuracy: 0.1000 - val_loss: 953.7050
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3672 - loss: 1.8176 - val_accuracy: 0.1001 - val_loss: 940.8348
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.3831 - loss: 1.6156 - val_accuracy: 0.1000 - val_loss: 6055.4492
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4062 - loss: 1.5423 - val_accuracy: 0.1000 - val_loss: 5980.7446
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3856 - loss: 1.6327 - val_accuracy: 0.1176 - val_loss: 2398.3787
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4297 - loss: 1.5428 - val_accuracy: 0.1195 - val_loss: 2375.8411
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.4102 - loss: 1.5838 - val_accuracy: 0.1021 - val_loss: 1225.3601
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4375 - loss: 1.5639 - val_accuracy: 0.1063 - val_loss: 1235.7446
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.4151 - loss: 1.5788 - val_accuracy: 0.1015 - val_loss: 2159.4663
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4297 - loss: 1.5488 - val_accuracy: 0.1014 - val_loss: 2146.3530

# %%
import os

save_dir = "models"
os.makedirs(save_dir, exist_ok = True)

for i in range(0, n):
    
    model = globals()[f'model{i}']
    
    model_path = os.path.join(save_dir, f'model_{i}.h5')
    model.save(model_path)
    print(f"Saved model {i} to {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model 0 to models\model_0.h5
# Saved model 1 to models\model_1.h5
# Saved model 2 to models\model_2.h5
# Saved model 3 to models\model_3.h5
# Saved model 4 to models\model_4.h5
